# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#imported required libraries

# %%
#checking files exist in present working directory (pwd)
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 164C-66EA
#
#  Directory of C:\Users\Divakar\Desktop\archive
#
# 07-12-2022  10:52    <DIR>          .
# 07-12-2022  10:52    <DIR>          ..
# 07-12-2022  10:50    <DIR>          .ipynb_checkpoints
# 07-12-2022  10:49         3,467,391 TMDB 10000 Movies Dataset.csv
# 07-12-2022  10:52               705 Untitled.ipynb
#                2 File(s)      3,468,096 bytes
#                3 Dir(s)  100,307,648,512 bytes free

# %%
#reading file from the location and assigned to variavle df
df = pd.read_csv("TMDB 10000 Movies Dataset.csv")

# %%
df
# Out:
#           id original_language             original_title  \
# 0     851644                ko                    20세기 소녀
# 1        238                en              The Godfather
# 2        278                en   The Shawshank Redemption
# 3        240                en      The Godfather Part II
# 4     667257                es           Cosas imposibles
# ...      ...               ...                        ...
# 9995   11375                en         Hollywood Homicide
# 9996  298614                fr  Une heure de tranquillité
# 9997   50357                en                  Apollo 18
# 9998   97795                en                     Emergo
# 9999   11822                de                Nekromantik
#
#                                                overview  popularity  \
# 0     Yeon-du asks her best friend Bora to collect a...     170.540
# 1     Spanning the years 1945 to 1955, a chronicle o...      86.518
# ...

# %%
#checking first 100 items from the list 
df.head(100)
# Out:
#         id original_language                        original_title  \
# 0   851644                ko                               20세기 소녀
# 1      238                en                         The Godfather
# 2      278                en              The Shawshank Redemption
# 3      240                en                 The Godfather Part II
# 4   667257                es                      Cosas imposibles
# ..     ...               ...                                   ...
# 95   77338                fr                          Intouchables
# 96  265177                fr                                 Mommy
# 97  299536                en                Avengers: Infinity War
# 98   10376                it  La leggenda del pianista sull'oceano
# 99    1585                en                 It's a Wonderful Life
#
#                                              overview  popularity  \
# 0   Yeon-du asks her best friend Bora to collect a...     170.540
# ...

# %%
#checking first 20 items from the list
df.head(20)
# Out:
#         id original_language                   original_title  \
# 0   851644                ko                          20세기 소녀
# 1      238                en                    The Godfather
# 2      278                en         The Shawshank Redemption
# 3      240                en            The Godfather Part II
# 4   667257                es                 Cosas imposibles
# 5    19404                hi     दिलवाले दुल्हनिया ले जायेंगे
# 6      424                en                 Schindler's List
# 7   620249                zh                            罗小黑战记
# 8   372754                ja                              同級生
# 9      129                ja                         千と千尋の神隠し
# 10     389                en                     12 Angry Men
# 11  372058                ja                            君の名は。
# 12  496243                ko                              기생충
# 13     497                en                   The Green Mile
# ...

# %%
#cheking information about the data set for missing and dtype details 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   original_language  10000 non-null  object
#  2   original_title     10000 non-null  object
#  3   overview           9994 non-null   object
#  4   popularity         10000 non-null  float64
#  5   release_date       10000 non-null  object
#  6   title              10000 non-null  object
#  7   vote_average       10000 non-null  float64
#  8   vote_count         10000 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.2+ KB

# %%
#to check columns exist in the df
df.columns
# Out:
# Index(['id', 'original_language', 'original_title', 'overview', 'popularity',
#        'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
#to check empty value columns as a bolean
df.isnull()
# Out:
#          id  original_language  original_title  overview  popularity  \
# 0     False              False           False     False       False
# 1     False              False           False     False       False
# 2     False              False           False     False       False
# 3     False              False           False     False       False
# 4     False              False           False     False       False
# ...     ...                ...             ...       ...         ...
# 9995  False              False           False     False       False
# 9996  False              False           False     False       False
# 9997  False              False           False     False       False
# 9998  False              False           False     False       False
# 9999  False              False           False     False       False
#
#       release_date  title  vote_average  vote_count
# 0            False  False         False       False
# ...

# %%
df.isnull().sum().index
# Out:
# Index(['id', 'original_language', 'original_title', 'overview', 'popularity',
#        'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
#to check null values as a count 
df.isnull().sum()
# Out:
# id                   0
# original_language    0
# original_title       0
# overview             6
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
#to fill empty cells and assigned to same data we use inplace = True (data cleaning)
df["overview"].fillna("All_overview", inplace=True)

# %%
#now cells are filled 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   original_language  10000 non-null  object
#  2   original_title     10000 non-null  object
#  3   overview           10000 non-null  object
#  4   popularity         10000 non-null  float64
#  5   release_date       10000 non-null  object
#  6   title              10000 non-null  object
#  7   vote_average       10000 non-null  float64
#  8   vote_count         10000 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.2+ KB

# %%
#to check integer and float values fron the data set
df.select_dtypes(include=["int64","float64"])
# Out:
#           id  popularity  vote_average  vote_count
# 0     851644     170.540           8.7         290
# 1        238      86.518           8.7       16988
# 2        278      84.681           8.7       22748
# 3        240      44.957           8.6       10293
# 4     667257      32.859           8.6         299
# ...      ...         ...           ...         ...
# 9995   11375       9.532           5.3         529
# 9996  298614       5.835           5.3         304
# 9997   50357      51.415           5.3         839
# 9998   97795       6.226           5.3         242
# 9999   11822       9.630           5.3         202
#
# [10000 rows x 4 columns]

# %%
#to check data set which column name as integer and floting values
df.select_dtypes(include=["int64","float64"]).columns
# Out:
# Index(['id', 'popularity', 'vote_average', 'vote_count'], dtype='object')

# %%
#to drop unwanted column, if want changes in same df use inplace=True

# %%
df.drop(columns=["original_title"],inplace=True)

# %%
df #now orginal_language is dropped from the data
# Out:
#           id original_language  \
# 0     851644                ko
# 1        238                en
# 2        278                en
# 3        240                en
# 4     667257                es
# ...      ...               ...
# 9995   11375                en
# 9996  298614                fr
# 9997   50357                en
# 9998   97795                en
# 9999   11822                de
#
#                                                overview  popularity  \
# 0     Yeon-du asks her best friend Bora to collect a...     170.540
# 1     Spanning the years 1945 to 1955, a chronicle o...      86.518
# 2     Framed in the 1940s for the double murder of h...      84.681
# 3     In the continuing saga of the Corleone crime f...      44.957
# 4     Matilde is a woman who, after the death of her...      32.859
# ...                                                 ...         ...
# 9995  Joe Gavilan and his new partner K. C. Calden, ...       9.532
# ...

# %%
#to filter out data where original_language vote is equals to en

df.loc[df['original_language']=="en"]
# Out:
#           id original_language  \
# 1        238                en
# 2        278                en
# 3        240                en
# 6        424                en
# 10       389                en
# ...      ...               ...
# 9992  553141                en
# 9994  505177                en
# 9995   11375                en
# 9997   50357                en
# 9998   97795                en
#
#                                                overview  popularity  \
# 1     Spanning the years 1945 to 1955, a chronicle o...      86.518
# 2     Framed in the 1940s for the double murder of h...      84.681
# 3     In the continuing saga of the Corleone crime f...      44.957
# 6     The true story of how businessman Oskar Schind...      52.121
# 10    The defense and the prosecution have rested an...      33.678
# ...                                                 ...         ...
# 9992  On the outskirts of a kingdom, a quiet but fie...      11.145
# ...

# %%
df
# Out:
#           id original_language  \
# 0     851644                ko
# 1        238                en
# 2        278                en
# 3        240                en
# 4     667257                es
# ...      ...               ...
# 9995   11375                en
# 9996  298614                fr
# 9997   50357                en
# 9998   97795                en
# 9999   11822                de
#
#                                                overview  popularity  \
# 0     Yeon-du asks her best friend Bora to collect a...     170.540
# 1     Spanning the years 1945 to 1955, a chronicle o...      86.518
# 2     Framed in the 1940s for the double murder of h...      84.681
# 3     In the continuing saga of the Corleone crime f...      44.957
# 4     Matilde is a woman who, after the death of her...      32.859
# ...                                                 ...         ...
# 9995  Joe Gavilan and his new partner K. C. Calden, ...       9.532
# ...

# %%
#replace tthe value 20th Century Girl to only first word

# %%
df["release_date"]=df["release_date"].apply(lambda x: x.split("-")[-1])

# %%
df
# Out:
#           id original_language  \
# 0     851644                ko
# 1        238                en
# 2        278                en
# 3        240                en
# 4     667257                es
# ...      ...               ...
# 9995   11375                en
# 9996  298614                fr
# 9997   50357                en
# 9998   97795                en
# 9999   11822                de
#
#                                                overview  popularity  \
# 0     Yeon-du asks her best friend Bora to collect a...     170.540
# 1     Spanning the years 1945 to 1955, a chronicle o...      86.518
# 2     Framed in the 1940s for the double murder of h...      84.681
# 3     In the continuing saga of the Corleone crime f...      44.957
# 4     Matilde is a woman who, after the death of her...      32.859
# ...                                                 ...         ...
# 9995  Joe Gavilan and his new partner K. C. Calden, ...       9.532
# ...

# %%
#plotting

# %%
#highest original languages

# %%
plt.figure(figsize = (18,8))
sns.countplot("original_language",data=df)
# Out:
# C:\Users\Divakar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='original_language', ylabel='count'>

# %%
plt.figure(figsize = (18,8))
sns.countplot("vote_average",data=df)
# Out:
# C:\Users\Divakar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='vote_average', ylabel='count'>

# %%
#calculate the the number of languges

# %%
df.columns
# Out:
# Index(['id', 'original_language', 'overview', 'popularity', 'release_date',
#        'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df["original_language"].value_counts()
# Out:
# en    7736
# fr     678
# it     430
# ja     288
# es     203
# de     105
# ko      84
# zh      65
# cn      62
# ru      49
# hi      46
# pt      45
# sv      38
# da      32
# no      22
# pl      17
# nl      13
# tr      12
# th      11
# hu       8
# fa       7
# fi       6
# id       6
# el       4
# sr       4
# is       3
# cs       3
# te       3
# ar       3
# ro       2
# eu       2
# et       1
# sh       1
# bs       1
# bn       1
# ml       1
# la       1
# uk       1
# af       1
# vi       1
# nb       1
# he       1
# km       1
# xx       1
# Name: original_language, dtype: int64
